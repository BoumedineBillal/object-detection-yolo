# %% [markdown]
# # Workshop: Introduction Object Detection using YOLO
#
# ## 1. Setting Up Kaggle and Downloading Car Plate Detection Dataset
#    - Install Kaggle API for dataset download
#    - Upload Kaggle API key
#    - Download the car plate detection dataset from Kaggle
#
# ## 2. Data Preprocessing and YOLO Labeling
#    - Load and preprocess the dataset
#    - Implement YOLO labeling for object detection
#    - Split the data into training and testing sets
#
# ## 3. Custom IoU Metric Function
#    - Explanation of Intersection over Union (IoU)
#    - Implementation of a custom IoU metric function
#    - Understanding IoU threshold and its significance
#
# ## 4. YOLO-based Object Detection Model Architecture
#    - Designing the architecture of a YOLO-based object detection model
#    - Explanation of each layer and its purpose
#    - Introduction to probability and bounding box prediction
#
# ## 5. Train the Model
#    - Compilation of the model with custom IoU metric
#    - Training the YOLO-based object detection model
#
# ## 6. Test the Model
#    - Evaluation of the trained model on test data
#    - Visualization of model predictions
#    - Discussion of results and potential improvements

# %%
# install the 'colorama' library for colored terminal text
# !pip install colorama
# Install gdown
# !pip install gdown
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# # 1. Setting Up Kaggle and Downloading Car Plate Detection Dataset

# %%
# Install Kaggle API for dataset download
# !pip install -q kaggle

# Download kaggle.json directly from the shared link using gdown
file_id = '1lWBhd5jbQdMWakb_6AJ2l01OdjjsmoBN'  # Replace with the correct file ID from your shared link
destination_path = '/content/kaggle.json'  # Change the destination path if needed

# Download the file using gdown
# !gdown --id $file_id -O $destination_path

# Create a directory for storing Kaggle API key
# !mkdir ~/.kaggle

# Move the uploaded Kaggle API key to the appropriate directory
# !cp kaggle.json ~/.kaggle/

# Set appropriate permissions for the Kaggle API key
# !chmod 600 ~/.kaggle/kaggle.json

# List available datasets on Kaggle
# !kaggle datasets list

# Download the car plate detection dataset from Kaggle
# !kaggle datasets download -d andrewmvd/car-plate-detection

# Create a directory to store the dataset and unzip the contents
# !mkdir train
# !unzip car-plate-detection.zip -d train

"""
# Install Kaggle API for dataset download
# !pip install -q kaggle

# Upload your Kaggle API key (kaggle.json) file
from google.colab import files
files.upload()

# Create a directory for storing Kaggle API key
# !mkdir ~/.kaggle

# Move the uploaded Kaggle API key to the appropriate directory
# !cp kaggle.json ~/.kaggle/

# Set appropriate permissions for the Kaggle API key
# !chmod 600 ~/.kaggle/kaggle.json

# List available datasets on Kaggle
# !kaggle datasets list

# Download the car plate detection dataset from Kaggle
# !kaggle datasets download -d andrewmvd/car-plate-detection

# Create a directory to store the dataset and unzip the contents
# !mkdir train
# !unzip car-plate-detection.zip -d train
"""
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1lWBhd5jbQdMWakb_6AJ2l01OdjjsmoBN
# To: /content/kaggle.json
# 100% 70.0/70.0 [00:00<00:00, 401kB/s]
# ref                                                  title                                       size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------  -----------------------------------------  -----  -------------------  -------------  ---------  ---------------
# thedrcat/daigt-v2-train-dataset                      DAIGT V2 Train Dataset                      29MB  2023-11-16 01:38:36           3019        251  1.0
# muhammadbinimran/housing-price-prediction-data       Housing Price Prediction Data              763KB  2023-11-21 17:56:32          12764        218  1.0
# rishabhkarn/ipl-auction-2023                         IPL Auction 2023                             4KB  2023-12-24 10:45:03            673         26  0.9411765
# bhavikjikadara/car-price-prediction-dataset          Car Price Prediction Dataset                 4KB  2023-12-23 07:07:54           1237         33  0.9411765
# thedevastator/global-video-game-sales-and-reviews    Global Video Game Sales and Reviews         56KB  2023-12-20 06:36:51           1243         31  1.0
# tonygordonjr/spotify-dataset-2023                    Spotify Dataset 2023                        96MB  2023-12-20 23:37:29           1044         31  1.0
# henryshan/2023-data-scientists-salary                2023 Data Scientists Salary                 25KB  2023-12-14 10:14:34           2329         48  1.0
# thedrcat/daigt-proper-train-dataset                  DAIGT Proper Train Dataset                 119MB  2023-11-05 14:03:25           2359        185  1.0
# thedrcat/daigt-external-train-dataset                DAIGT External Train Dataset               435MB  2023-11-06 17:10:37            468         54  1.0
# sujaykapadnis/official-netflix-streaming-data        Official Netflix Viewership Database         2MB  2023-12-20 16:30:11            813         27  1.0
# henryshan/starbucks                                  Starbucks                                    5KB  2023-12-06 03:07:49           4489         99  1.0
# vassyesboy/netflix-engagement-jan-jun-23             Netflix Engagement (Jan - Jun 23) +          2MB  2023-12-15 11:58:07           1241         30  1.0
# thedrcat/daigt-v3-train-dataset                      daigt-v3-train-dataset                      83MB  2023-12-28 04:36:42            209         45  1.0
# dansbecker/melbourne-housing-snapshot                Melbourne Housing Snapshot                 451KB  2018-06-05 12:52:24         134270       1407  0.7058824
# thedevastator/netflix-imdb-scores                    Netflix IMDB Scores                        699KB  2023-12-03 14:10:34           5465         97  1.0
# elanderos/motivations-for-fashion-shopping-in-china  Motivations for Fashion Shopping in China  408KB  2023-12-23 18:17:46            390         22  1.0
# thedevastator/film-genre-statistics                  Film Genre Statistics                       36KB  2023-12-19 06:45:48           1143         29  1.0
# elvinrustam/books-dataset                            Books Dataset                               53MB  2023-12-20 20:46:34           1069         31  1.0
# thedevastator/video-game-sales-and-ratings           Video Game Sales and Ratings               540KB  2023-12-20 07:10:36            800         29  1.0
# andreinovikov/air-pollution                          Air pollution                               96KB  2023-12-05 12:00:34           1181         25  1.0
# Downloading car-plate-detection.zip to /content
#  98% 200M/203M [00:09<00:00, 22.1MB/s]
# 100% 203M/203M [00:09<00:00, 21.4MB/s]
# Archive:  car-plate-detection.zip
#   inflating: train/annotations/Cars0.xml
#   inflating: train/annotations/Cars1.xml
#   inflating: train/annotations/Cars10.xml
#   inflating: train/annotations/Cars100.xml
#   inflating: train/annotations/Cars101.xml
#   inflating: train/annotations/Cars102.xml
#   inflating: train/annotations/Cars103.xml
#   inflating: train/annotations/Cars104.xml
#   inflating: train/annotations/Cars105.xml
#   inflating: train/annotations/Cars106.xml
#   inflating: train/annotations/Cars107.xml
#   inflating: train/annotations/Cars108.xml
#   inflating: train/annotations/Cars109.xml
#   inflating: train/annotations/Cars11.xml
#   inflating: train/annotations/Cars110.xml
#   inflating: train/annotations/Cars111.xml
#   inflating: train/annotations/Cars112.xml
#   inflating: train/images/Cars85.png
#   inflating: train/images/Cars86.png
#   inflating: train/images/Cars87.png
#   inflating: train/images/Cars88.png
#   inflating: train/images/Cars89.png
#   inflating: train/images/Cars9.png
#   inflating: train/images/Cars90.png
#   inflating: train/images/Cars91.png
#   inflating: train/images/Cars92.png
#   inflating: train/images/Cars93.png
#   inflating: train/images/Cars94.png
#   inflating: train/images/Cars95.png
#   inflating: train/images/Cars96.png
#   inflating: train/images/Cars97.png
#   inflating: train/images/Cars98.png
#   inflating: train/images/Cars99.png
# '\n# Install Kaggle API for dataset download\n!pip install -q kaggle\n\n# Upload your Kaggle API key (kaggle.json) file\nfrom google.colab import files\nfiles.upload()\n\n# Create a directory for storing Kaggle API key\n!mkdir ~/.kaggle\n\n# Move the uploaded Kaggle API key to the appropriate directory\n!cp kaggle.json ~/.kaggle/\n\n# Set appropriate permissions for the Kaggle API key\n!chmod 600 ~/.kaggle/kaggle.json\n\n# List available datasets on Kaggle\n!kaggle datasets list\n\n# Download the car plate detection dataset from Kaggle\n!kaggle datasets download -d andrewmvd/car-plate-detection\n\n# Create a directory to store the dataset and unzip the contents\n!mkdir train\n!unzip car-plate-detection.zip -d train\n'

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras import layers, backend as K
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from colorama import Fore
import sys

# %% [markdown]
# Visualizing an Example Car Image

# %%
# Set the default figure size for matplotlib
plt.rcParams["figure.figsize"] = (8, 8)

# Create a subplot
plt.subplot(1, 1, 1)

# Specify the path for the example car image (adjust the index as needed)
image_index = 40
image_path = f"train/images/Cars{image_index}.png"

# Load the image using PIL and convert it to a NumPy array
image_array = np.array(Image.open(image_path))

# Display the image using matplotlib
plt.imshow(image_array)

# Show the plot
plt.show()

# %% [markdown]
# # 2. Data Preprocessing and YOLO Labeling
#
# # Creating YOLO Labels
#
# ## Bounding Box Information Extraction from XML (Annotations):
#
# The dataset includes XML annotation files corresponding to each image. These files contain information about the bounding boxes of objects, specifically cars in this case. The function `get_` is employed to extract specific information such as xmin, ymin, xmax, and ymax from the XML annotations.
#
# ## Scaling and Resizing Images:
#
# Images are loaded and converted to the RGB format. Scaling factors (`im_y_scale` and `im_x_scale`) are calculated based on the original image dimensions to normalize pixel values. Subsequently, the images are resized to a standardized size of 256x256 pixels.
#
# ## Creating YOLO Labels:
#
# YOLO requires a specific label format to facilitate object detection. This involves dividing the image into a grid, typically a 16x16 grid in this case.
#
# ### Understanding the Grid System:
#
# - The image is conceptually divided into a grid of cells.
# - Each cell is associated with a specific region of the image.
# - For a 16x16 grid, there are 256 cells in total.
# - The objective is to predict whether an object is present in each cell and, if so, define the bounding box for that object.
#
# ### Assigning Bounding Boxes to Grid Cells:
#
# - Bounding box information extracted from XML annotations is converted to YOLO label format.
# - The coordinates of the top-left corner (`x1, y1`) and bottom-right corner (`x2, y2`) of the bounding box are calculated.
# - The grid coordinates (`mx, my`) of the cell containing the object's center are determined.
#
# ### Probability and Localization:
#
# - A probability value is assigned to each cell, indicating the likelihood of an object being present.
# - The x and y coordinates of the bounding box within the cell are calculated to represent the localization of the object.
#
# ### Prevention of Duplicated Labels:
#
# - To prevent duplicated labels, it is checked whether a cell already has an assigned label.
# - If a label is present, the process skips that cell to avoid redundancy.
#
# These YOLO labels are then stored in the `y_train` array for training the YOLO model. This grid-based approach enhances the model's ability to detect and localize objects efficiently in various regions of the image.

# %%
# Function to extract bounding box information from XML
def get_(bndbox, p):
    return int(bndbox.find(p).text)

# Directory path containing the images
directory_path = "train/images/"

# Calculate the actual number of images in the directory
data_size = len([file for file in os.listdir(directory_path) if file.endswith(".png")])

# Initialize arrays to store images and labels
x_train = np.zeros((data_size, 256, 256, 3), dtype=np.float32)
y_train = np.zeros((data_size, 16, 16, 5), dtype=np.float32)

# Define grid size for YOLO labels
grid_size = 16

# Iterate through each image in the dataset with a progress bar
for image_index in tqdm(range(data_size), position=0, leave=True, file=sys.stdout, bar_format="{l_bar}%s{bar}%s{r_bar}" % (Fore.BLUE, Fore.RESET), desc="Processing Images"):
    # Construct paths for image and annotation files
    image_path = f"train/images/Cars{image_index}.png"
    annotation_path = f"train/annotations/Cars{image_index}.xml"

    # Load the image and convert it to RGB
    image = np.array(Image.open(image_path).convert('RGB'))

    # Calculate scaling factors for resizing
    im_y_scale = 255.0 / image.shape[0]
    im_x_scale = 255.0 / image.shape[1]

    # Resize the image and normalize pixel values
    x_train[image_index, :, :, :] = cv2.resize(image, (256, 256)) / 255.0

    # Extract bounding box information from the XML annotation
    boxes = []
    tree = ET.parse(annotation_path)
    root = tree.getroot()
    for object_ in root.findall('object'):
        for bndbox in object_.findall('bndbox'):
            boxes.append([get_(bndbox, 'xmin'), get_(bndbox, 'ymin'), get_(bndbox, 'xmax'), get_(bndbox, 'ymax')])

    # Convert boxes from image_size to 256*256 size
    boxes = [[boxe[0] * im_x_scale, boxe[1] * im_y_scale, (boxe[2] - boxe[0]) * im_x_scale, (boxe[3] - boxe[1]) * im_y_scale] for boxe in boxes]

    # Process bounding boxes and create YOLO labels
    for boxe in boxes:
        px, py = boxe[0], boxe[1]
        mx, my = int((px + int(boxe[2] / 2)) // grid_size), int((py + int(boxe[3] / 2)) // grid_size)

        # Channels for YOLO labels
        channels = y_train[image_index, :, :, :][my][mx]

        # Prevent duplicated labels
        if channels[0] > 0:
            continue

        # Set YOLO label values
        channels[0] = 1.0  # Probability
        channels[1] = px - (mx * grid_size)  # x1
        channels[2] = py - (my * grid_size)  # y1
        channels[3] = boxe[2]  # x2
        channels[4] = boxe[3]  # y2

# Split the data into training and testing sets
test_size = 0.1
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=test_size, random_state=42)


# Show summary of data
print("Data Summary:")
print(f"Total Samples: {data_size}")
print(f"Train Samples: {len(x_train)}")
print(f"Test Samples: {len(x_test)}")
print(f"Image Shape: {x_train.shape[1:]}")
print(f"Label Shape: {y_train.shape[1:]} - Represents a grid of 16x16 cells, where each cell has 5 values: [Probability, x1, y1, x2, y2] for object detection.")
# Out:
# Processing Images: 100%|██████████| 433/433 [00:14<00:00, 30.05it/s]
# Data Summary:
# Total Samples: 433
# Train Samples: 389
# Test Samples: 44
# Image Shape: (256, 256, 3)
# Label Shape: (16, 16, 5) - Represents a grid of 16x16 cells, where each cell has 5 values: [Probability, x1, y1, x2, y2] for object detection.

# %% [markdown]
# Visualizing YOLO Predictions with Grid and Probability-based Colors

# %%
# Function to get color based on probability for visualization
def get_color_by_probability(p):
    if p < 0.3:
        return (1., 0., 0.)
    if p < 0.7:
        return (1., 1., 0.)
    return (0., 1., 0.)

# Function to show predictions
def show_predict(X, y, threshold=0.1, draw_grid=True):
    fig, ax = plt.subplots(1)
    ax.imshow(X)

    if draw_grid:
        # Draw vertical grid lines
        for mx in range(1, 16):
            ax.axvline(mx * grid_size, color='white', linestyle='--', linewidth=1)
        # Draw horizontal grid lines
        for my in range(1, 16):
            ax.axhline(my * grid_size, color='white', linestyle='--', linewidth=1)

    for mx in range(16):
        for my in range(16):
            channels = y[my][mx]
            prob, x1, y1, x2, y2 = channels[:5]

            # If probability is below the threshold, skip
            if prob < threshold:
                continue

            # Get color based on probability
            color = get_color_by_probability(prob)

            # Handle cases where width or height is 0
            width = max(1, x2)
            height = max(1, y2)

            # Draw bounding box
            px, py = (mx * grid_size) + x1, (my * grid_size) + y1

            rect = patches.Rectangle((px, py), width, height, linewidth=1, edgecolor=color, facecolor='none')
            ax.add_patch(rect)

            if draw_grid:
                # Colorize the grid with 0.5 transparent blue
                grid_rect = patches.Rectangle((mx * grid_size, my * grid_size), grid_size, grid_size, linewidth=1, edgecolor='none', facecolor=(0, 0, 1, 0.5))
                ax.add_patch(grid_rect)

            # Draw label using text with adjusted text thickness
            class_name = "plate"
            label_text = f'{class_name}'
            plt.text(px, py , label_text, color=color, fontsize=12, fontweight='bold', ha='left', va='bottom')

    plt.show()

index = 40
show_predict(x_train[index], y_train[index])

# %% [markdown]
# # 3. Custom IoU Metric Function
#
# ![Custom IoU Metric](https://drive.google.com/uc?export=view&id=1DQfHuWHqXNIzLNvOEdjyHpTGxst4Rfv7)
#
# ## Objective:
# The Custom IoU (Intersection over Union) metric is designed to evaluate the accuracy of object detection predictions. IoU measures the overlap between predicted bounding boxes and ground truth bounding boxes. Let's break down the key concepts step by step.
#
# ## Input Parameters:
# - `y_true`: Ground truth labels representing actual object locations.
# - `y_pred`: Predicted labels generated by the model.
# - `threshold`: IoU threshold for considering a prediction as correct (default is 0.5).
#
# ## Reshaping Labels:
# - The ground truth (`y_true`) and predicted labels (`y_pred`) are reshaped to facilitate computation.
# - Each label is reshaped into a 4D tensor with dimensions (batch_size, 16, 16, 5), where 16x16 represents the grid cells and 5 represents the YOLO label components (probability, x, y, width, height).
#
# ## Extracting Box Information:
# - The x, y, width, and height components are extracted from both ground truth and predicted labels.
#
# ## Calculating Overlaps:
# - The function computes the overlaps in the x and y dimensions between true and predicted bounding boxes.
# - It calculates the intersection and union areas based on these overlaps.
#
# ## Computing IoU:
# - IoU is calculated as the ratio of the intersection area to the union area, considering a small epsilon to avoid division by zero.
#
# ## Applying Threshold and Probability:
# - A binary mask is created based on the IoU exceeding the specified threshold and the ground truth probability being greater than or equal to 0.5.
#
# ## Weighted IoU Calculation:
# - The final step involves calculating the weighted mean IoU, considering only the relevant bounding boxes that meet the threshold and probability criteria.
# - The result is normalized by the batch size.
#
# ## Conclusion:
# The Custom IoU Metric function provides a comprehensive evaluation of the model's ability to accurately predict object locations, considering both spatial overlap and confidence in predictions.

# %%
# Custom IoU metric function with threshold and probability
def iou_metric(y_true, y_pred, threshold=0.5):
    """
    Calculate Intersection over Union (IoU) as a custom metric.

    Parameters:
    - y_true: Ground truth labels.
    - y_pred: Predicted labels.
    - threshold: IoU threshold for considering a prediction as correct.

    Returns:
    - IoU: Intersection over Union.
    """
    box_true = K.reshape(y_true, (-1, 16, 16, 5))
    box_pred = K.reshape(y_pred, (-1, 16, 16, 5))

    true_box = box_true[:, :, :, 1:]
    pred_box = box_pred[:, :, :, 1:]

    true_prob = box_true[:, :, :, 0]
    pred_prob = box_pred[:, :, :, 0]

    x_true, y_true, w_true, h_true = tf.split(true_box, 4, axis=-1)
    x_pred, y_pred, w_pred, h_pred = tf.split(pred_box, 4, axis=-1)

    w_overlap = K.maximum(0.0, K.minimum(x_true + w_true, x_pred + w_pred) - K.maximum(x_true, x_pred))
    h_overlap = K.maximum(0.0, K.minimum(y_true + h_true, y_pred + h_pred) - K.maximum(y_true, y_pred))

    intersection = w_overlap * h_overlap
    union = w_true * h_true + w_pred * h_pred - intersection

    iou = intersection / (union + K.epsilon())  # Avoid division by zero

    # Squeeze the extra dimension in iou
    iou = K.squeeze(iou, axis=-1)

    # Apply threshold and consider probability
    mask = (iou >= threshold) & (true_prob >= 0.5)

    # Calculate mean IoU
    weighted_iou = K.sum(K.sum(iou * K.cast(mask, dtype=tf.float32), axis=[1, 2]) / (K.sum(K.cast(mask, dtype=tf.float32), axis=[1, 2]) + K.epsilon())) / K.cast(K.shape(y_true)[0], dtype=tf.float32)

    return weighted_iou

# %% [markdown]
# # 4. YOLO-based Object Detection Model Architecture
#
# ![Custom IoU Metric](https://drive.google.com/uc?export=view&id=1tieErxdqXtMw0XSr-ZvV34NdgoVfE65H)
#
# ## Objective:
# This section defines the architecture of a YOLO-based object detection model for predicting object probabilities and bounding box coordinates.
#
# ## Model Architecture:
# The model comprises a series of convolutional layers with Leaky ReLU activation, batch normalization, and downsampling to capture hierarchical features at different scales. The final output consists of a probability map and bounding box coordinates.
#
# ### Architecture Details:
# 1. **Input Layer:**
#    - Shape: (256, 256, 3)
#
# 2. **Feature Extraction Blocks:**
#    - Conv2D (16 filters, kernel_size=3, LeakyReLU activation, strides=2)
#    - BatchNormalization
#    - Conv2D (32 filters, kernel_size=3, LeakyReLU activation)
#    - BatchNormalization
#    - Conv2D (64 filters, kernel_size=3, LeakyReLU activation, strides=2)
#    - BatchNormalization
#    - Conv2D (128 filters, kernel_size=3, LeakyReLU activation, strides=2)
#    - BatchNormalization
#    - Conv2D (256 filters, kernel_size=3, LeakyReLU activation, strides=2)
#    - BatchNormalization
#
# 3. **Prediction Heads:**
#    - `x_prob`: Conv2D layer with 1 filter, kernel_size=3, sigmoid activation for probability prediction.
#    - `x_boxes`: Conv2D layer with 4 filters, kernel_size=3 for bounding box coordinates prediction.
#
# 4. **Gate Operation:**
#    - Utilizes a threshold gate (0.5) on `x_prob` to activate or deactivate bounding box predictions.
#
# 5. **Concatenation:**
#    - Concatenates the probability map (`x_prob`) and adjusted bounding box predictions (`x_boxes`).
#
# ## Loss Functions:
# - Two distinct loss functions are defined for probability and bounding box predictions.
# - Mean Squared Error (MSE) is used for bounding box predictions.
# - Binary Crossentropy is used for probability predictions.
# - Overall loss combines both probability and bounding box losses.
#
# ## Training Configuration:
# - Optimizer: Adam with a learning rate of 0.003.
# - Metrics: Custom Intersection over Union (IoU) metric is used for model evaluation.

# %%
# Input layer definition
x = x_input = layers.Input(shape=(256, 256, 3))

# First convolutional block
x = layers.Conv2D(16, kernel_size=3, padding='same', activation='LeakyReLU', strides=2)(x)
x = layers.BatchNormalization()(x)  # size: 128x128

# Second convolutional block
x = layers.Conv2D(32, kernel_size=3, padding='same', activation='LeakyReLU')(x)
x = layers.BatchNormalization()(x)  # size: 128x128

# Third convolutional block
x = layers.Conv2D(64, kernel_size=3, padding='same', activation='LeakyReLU', strides=2)(x)
x = layers.BatchNormalization()(x)  # size: 64x64

# Fourth convolutional block
x = layers.Conv2D(128, kernel_size=3, padding='same', activation='LeakyReLU', strides=2)(x)
x = layers.BatchNormalization()(x)  # size: 32x32

# Fifth convolutional block
x = layers.Conv2D(256, kernel_size=3, padding='same', activation='LeakyReLU', strides=2)(x)
x = layers.BatchNormalization()(x)  # size: 16x16 = grid_size

# Separate prediction heads for probability and bounding boxes
x_prob = layers.Conv2D(1, kernel_size=3, padding='same', activation='sigmoid', name='x_prob')(x)
x_boxes = layers.Conv2D(4, kernel_size=3, padding='same', name='x_boxes')(x)

# Apply threshold gate to probability predictions
gate = tf.where(x_prob > 0.5, tf.ones_like(x_prob), tf.zeros_like(x_prob))
x_boxes = x_boxes * gate

# Concatenate probability and bounding box predictions
x = layers.Concatenate()([x_prob, x_boxes])

# Indices for probability and bounding box channels
idx_p = [0]
idx_bb = [1, 2, 3, 4]

# Define loss functions
@tf.function
def loss_bb(y_true, y_pred):
    y_true = tf.gather(y_true, idx_bb, axis=-1)
    y_pred = tf.gather(y_pred, idx_bb, axis=-1)
    loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
    return tf.reduce_mean(loss[loss > 0.0])

@tf.function
def loss_p(y_true, y_pred):
    y_true = tf.gather(y_true, idx_p, axis=-1)
    y_pred = tf.gather(y_pred, idx_p, axis=-1)
    loss = tf.losses.binary_crossentropy(y_true, y_pred)
    return tf.reduce_sum(loss)

@tf.function
def loss_func(y_true, y_pred):
    # Combined loss function for probability and bounding boxes
    return loss_bb(y_true, y_pred) + loss_p(y_true, y_pred)

# Create and compile the model
model = tf.keras.models.Model(x_input, x)
model.summary()
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss=loss_func, optimizer=opt, metrics=[iou_metric])

# Function to preview model predictions
def preview(numbers=None, threshold=0.1):
    X = (x_train[0])[np.newaxis, :, :, :]
    y = model.predict(X, verbose=0)
    show_predict(X[0], y[0], threshold=threshold)

preview()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 128, 128, 16)         448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 16)         64        ['conv2d[0][0]']
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)         4640      ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 32)         128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)           18496     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 64, 64, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)          73856     ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  batch_normalization_3 (Bat  (None, 32, 32, 128)          512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)          295168    ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 16, 16, 256)          1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  x_prob (Conv2D)             (None, 16, 16, 1)            2305      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  tf.math.greater (TFOpLambd  (None, 16, 16, 1)            0         ['x_prob[0][0]']
#  a)
#
#  tf.ones_like (TFOpLambda)   (None, 16, 16, 1)            0         ['x_prob[0][0]']
#
#  tf.zeros_like (TFOpLambda)  (None, 16, 16, 1)            0         ['x_prob[0][0]']
#
#  x_boxes (Conv2D)            (None, 16, 16, 4)            9220      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  tf.where (TFOpLambda)       (None, 16, 16, 1)            0         ['tf.math.greater[0][0]',
#                                                                      'tf.ones_like[0][0]',
#                                                                      'tf.zeros_like[0][0]']
#
#  tf.math.multiply (TFOpLamb  (None, 16, 16, 4)            0         ['x_boxes[0][0]',
#  da)                                                                 'tf.where[0][0]']
#
#  concatenate (Concatenate)   (None, 16, 16, 5)            0         ['x_prob[0][0]',
#                                                                      'tf.math.multiply[0][0]']
#
# ==================================================================================================
# Total params: 406117 (1.55 MB)
# Trainable params: 405125 (1.55 MB)
# Non-trainable params: 992 (3.88 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Train the model

# %%
# Batch size and number of epochs
batch_size = 64
epochs = 300

# Train the model using the specified batch size, epochs, and validation data
model.fit(x_train,
          y_train,
          batch_size=batch_size,  #
          epochs=epochs,
          shuffle=True,  # Shuffle the training data at the beginning of each epoch
          validation_data=(x_test, y_test))  # Validation data to monitor model performance during training

# save the model
model.save("last_plate_detection_model.h5")
# Out:
# Epoch 1/300
# 7/7 [==============================] - 17s 415ms/step - loss: 29048.7324 - iou_metric: 0.0000e+00 - val_loss: 2968.5945 - val_iou_metric: 0.0000e+00
# Epoch 2/300
# 7/7 [==============================] - 1s 103ms/step - loss: 10381.3984 - iou_metric: 0.0000e+00 - val_loss: 3328.5908 - val_iou_metric: 0.0000e+00
# Epoch 3/300
# 7/7 [==============================] - 1s 103ms/step - loss: 6005.2524 - iou_metric: 0.0000e+00 - val_loss: 5461.8823 - val_iou_metric: 0.0000e+00
# Epoch 4/300
# 7/7 [==============================] - 1s 104ms/step - loss: 3302.4309 - iou_metric: 0.0000e+00 - val_loss: 1732.9374 - val_iou_metric: 0.0000e+00
# Epoch 5/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2261.0566 - iou_metric: 0.0000e+00 - val_loss: 1627.7827 - val_iou_metric: 0.0000e+00
# Epoch 6/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2222.5354 - iou_metric: 0.0000e+00 - val_loss: 1527.7974 - val_iou_metric: 0.0000e+00
# Epoch 7/300
# 7/7 [==============================] - 1s 100ms/step - loss: 2382.9707 - iou_metric: 0.0000e+00 - val_loss: 1848.4480 - val_iou_metric: 0.0000e+00
# Epoch 8/300
# 7/7 [==============================] - 1s 113ms/step - loss: 2413.2217 - iou_metric: 0.0000e+00 - val_loss: 1835.7375 - val_iou_metric: 0.0000e+00
# Epoch 9/300
# 7/7 [==============================] - 1s 134ms/step - loss: 2418.0261 - iou_metric: 0.0000e+00 - val_loss: 1822.7710 - val_iou_metric: 0.0000e+00
# Epoch 10/300
# 7/7 [==============================] - 1s 127ms/step - loss: 2495.9558 - iou_metric: 0.0000e+00 - val_loss: 1815.3888 - val_iou_metric: 0.0000e+00
# Epoch 11/300
# 7/7 [==============================] - 1s 129ms/step - loss: 2390.4863 - iou_metric: 0.0000e+00 - val_loss: 1809.1288 - val_iou_metric: 0.0000e+00
# Epoch 12/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2426.6497 - iou_metric: 0.0000e+00 - val_loss: 1802.8956 - val_iou_metric: 0.0000e+00
# Epoch 13/300
# 7/7 [==============================] - 1s 101ms/step - loss: 2384.5171 - iou_metric: 0.0015 - val_loss: 1800.3550 - val_iou_metric: 0.0000e+00
# Epoch 14/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2393.0215 - iou_metric: 0.0253 - val_loss: 1791.2362 - val_iou_metric: 0.0000e+00
# Epoch 15/300
# 7/7 [==============================] - 1s 103ms/step - loss: 2300.9290 - iou_metric: 0.0011 - val_loss: 1793.6945 - val_iou_metric: 0.0000e+00
# Epoch 16/300
# 7/7 [==============================] - 1s 142ms/step - loss: 2376.6201 - iou_metric: 0.0000e+00 - val_loss: 1779.2013 - val_iou_metric: 0.0000e+00
# Epoch 17/300
# 7/7 [==============================] - 1s 103ms/step - loss: 2308.3381 - iou_metric: 0.0000e+00 - val_loss: 1779.9550 - val_iou_metric: 0.0000e+00
# Epoch 18/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2328.6335 - iou_metric: 0.0027 - val_loss: 1774.9686 - val_iou_metric: 0.0000e+00
# Epoch 19/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2219.8103 - iou_metric: 0.0124 - val_loss: 1782.8540 - val_iou_metric: 0.0000e+00
# Epoch 20/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2218.0317 - iou_metric: 0.0077 - val_loss: 1774.2550 - val_iou_metric: 0.0000e+00
# Epoch 21/300
# 7/7 [==============================] - 1s 102ms/step - loss: 2210.3091 - iou_metric: 0.0050 - val_loss: 1766.2313 - val_iou_metric: 0.0000e+00
# Epoch 22/300
# 7/7 [==============================] - 1s 101ms/step - loss: 2168.0847 - iou_metric: 0.0143 - val_loss: 1764.2130 - val_iou_metric: 0.0000e+00
# Epoch 23/300
# 7/7 [==============================] - 1s 101ms/step - loss: 2202.7712 - iou_metric: 0.0228 - val_loss: 1766.2827 - val_iou_metric: 0.0000e+00
# Epoch 24/300
# 7/7 [==============================] - 1s 106ms/step - loss: 2113.4463 - iou_metric: 0.0483 - val_loss: 1761.5398 - val_iou_metric: 0.0000e+00
# Epoch 25/300
# 7/7 [==============================] - 1s 113ms/step - loss: 2161.5232 - iou_metric: 0.0245 - val_loss: 1767.9507 - val_iou_metric: 0.0000e+00
# Epoch 26/300
# 7/7 [==============================] - 1s 125ms/step - loss: 2071.7405 - iou_metric: 0.0394 - val_loss: 1744.8901 - val_iou_metric: 0.0000e+00
# Epoch 27/300
# 7/7 [==============================] - 1s 122ms/step - loss: 2065.8875 - iou_metric: 0.0552 - val_loss: 1748.1561 - val_iou_metric: 0.0000e+00
# Epoch 28/300
# 7/7 [==============================] - 1s 127ms/step - loss: 2052.2812 - iou_metric: 0.0473 - val_loss: 1753.7085 - val_iou_metric: 0.0000e+00
# Epoch 29/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2065.9250 - iou_metric: 0.0384 - val_loss: 1732.9175 - val_iou_metric: 0.0000e+00
# Epoch 30/300
# 7/7 [==============================] - 1s 105ms/step - loss: 2018.7473 - iou_metric: 0.0426 - val_loss: 1731.6840 - val_iou_metric: 0.0000e+00
# Epoch 31/300
# 7/7 [==============================] - 1s 102ms/step - loss: 1912.2072 - iou_metric: 0.0563 - val_loss: 1750.0669 - val_iou_metric: 0.0000e+00
# Epoch 32/300
# 7/7 [==============================] - 1s 105ms/step - loss: 2052.6428 - iou_metric: 0.0521 - val_loss: 1748.3594 - val_iou_metric: 0.0000e+00
# Epoch 33/300
# 7/7 [==============================] - 1s 103ms/step - loss: 1874.1632 - iou_metric: 0.0690 - val_loss: 1726.3560 - val_iou_metric: 0.0000e+00
# Epoch 34/300
# 7/7 [==============================] - 1s 106ms/step - loss: 1935.5219 - iou_metric: 0.0644 - val_loss: 1728.7172 - val_iou_metric: 0.0000e+00
# Epoch 35/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1839.2247 - iou_metric: 0.1466 - val_loss: 1710.6532 - val_iou_metric: 0.0000e+00
# Epoch 36/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1842.2988 - iou_metric: 0.1045 - val_loss: 1687.8820 - val_iou_metric: 0.0000e+00
# Epoch 37/300
# 7/7 [==============================] - 1s 104ms/step - loss: 2009.9004 - iou_metric: 0.0779 - val_loss: 1593.9081 - val_iou_metric: 0.0000e+00
# Epoch 38/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1827.8429 - iou_metric: 0.1155 - val_loss: 1543.1602 - val_iou_metric: 0.0000e+00
# Epoch 39/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1706.3577 - iou_metric: 0.1471 - val_loss: 1406.0210 - val_iou_metric: 0.0000e+00
# Epoch 40/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1821.9685 - iou_metric: 0.1355 - val_loss: 1526.0840 - val_iou_metric: 0.0000e+00
# Epoch 41/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1639.4756 - iou_metric: 0.1424 - val_loss: 1611.0294 - val_iou_metric: 0.0000e+00
# Epoch 42/300
# 7/7 [==============================] - 1s 109ms/step - loss: 1607.0243 - iou_metric: 0.1730 - val_loss: 1557.0382 - val_iou_metric: 0.0000e+00
# Epoch 43/300
# 7/7 [==============================] - 1s 120ms/step - loss: 1653.3506 - iou_metric: 0.1716 - val_loss: 1541.5183 - val_iou_metric: 0.0000e+00
# Epoch 44/300
# 7/7 [==============================] - 1s 122ms/step - loss: 1557.7386 - iou_metric: 0.1728 - val_loss: 1533.3613 - val_iou_metric: 0.0146
# Epoch 45/300
# 7/7 [==============================] - 1s 136ms/step - loss: 1452.9940 - iou_metric: 0.1626 - val_loss: 1402.9053 - val_iou_metric: 0.0000e+00
# Epoch 46/300
# 7/7 [==============================] - 1s 109ms/step - loss: 1489.9137 - iou_metric: 0.1644 - val_loss: 1431.8763 - val_iou_metric: 0.0118
# Epoch 47/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1566.5540 - iou_metric: 0.1677 - val_loss: 1522.7012 - val_iou_metric: 0.0117
# Epoch 48/300
# 7/7 [==============================] - 1s 103ms/step - loss: 1518.5793 - iou_metric: 0.2015 - val_loss: 1538.9005 - val_iou_metric: 0.0121
# Epoch 49/300
# 7/7 [==============================] - 1s 106ms/step - loss: 1369.1885 - iou_metric: 0.2009 - val_loss: 1429.0074 - val_iou_metric: 0.0137
# Epoch 50/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1310.0103 - iou_metric: 0.2127 - val_loss: 1529.3860 - val_iou_metric: 0.0119
# Epoch 51/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1326.0111 - iou_metric: 0.2984 - val_loss: 1495.4862 - val_iou_metric: 0.0000e+00
# Epoch 52/300
# 7/7 [==============================] - 1s 103ms/step - loss: 1286.7885 - iou_metric: 0.2390 - val_loss: 1489.0398 - val_iou_metric: 0.0000e+00
# Epoch 53/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1266.8982 - iou_metric: 0.2159 - val_loss: 1499.1055 - val_iou_metric: 0.0137
# Epoch 54/300
# 7/7 [==============================] - 1s 103ms/step - loss: 1296.8149 - iou_metric: 0.2164 - val_loss: 1133.7888 - val_iou_metric: 0.0132
# Epoch 55/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1319.6704 - iou_metric: 0.2394 - val_loss: 1454.9634 - val_iou_metric: 0.0287
# Epoch 56/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1181.1183 - iou_metric: 0.2722 - val_loss: 1488.8540 - val_iou_metric: 0.0000e+00
# Epoch 57/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1380.6447 - iou_metric: 0.1769 - val_loss: 1295.2570 - val_iou_metric: 0.0418
# Epoch 58/300
# 7/7 [==============================] - 1s 105ms/step - loss: 1294.8390 - iou_metric: 0.2230 - val_loss: 1156.4268 - val_iou_metric: 0.0124
# Epoch 59/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1298.3051 - iou_metric: 0.2122 - val_loss: 1484.8027 - val_iou_metric: 0.0486
# Epoch 60/300
# 7/7 [==============================] - 1s 122ms/step - loss: 1283.0281 - iou_metric: 0.2714 - val_loss: 1576.6681 - val_iou_metric: 0.0297
# Epoch 61/300
# 7/7 [==============================] - 1s 117ms/step - loss: 1232.3400 - iou_metric: 0.2268 - val_loss: 1275.8342 - val_iou_metric: 0.0791
# Epoch 62/300
# 7/7 [==============================] - 1s 122ms/step - loss: 1118.8253 - iou_metric: 0.2893 - val_loss: 1456.7388 - val_iou_metric: 0.0473
# Epoch 63/300
# 7/7 [==============================] - 1s 134ms/step - loss: 1180.3462 - iou_metric: 0.2497 - val_loss: 1479.0195 - val_iou_metric: 0.0439
# Epoch 64/300
# 7/7 [==============================] - 1s 107ms/step - loss: 1310.6475 - iou_metric: 0.2785 - val_loss: 1509.3690 - val_iou_metric: 0.0456
# Epoch 65/300
# 7/7 [==============================] - 1s 104ms/step - loss: 1233.1636 - iou_metric: 0.2515 - val_loss: 1375.4751 - val_iou_metric: 0.0262
# Epoch 66/300
# 7/7 [==============================] - 1s 107ms/step - loss: 1073.6603 - iou_metric: 0.2511 - val_loss: 1399.0046 - val_iou_metric: 0.0607
# Epoch 67/300
# 7/7 [==============================] - 1s 163ms/step - loss: 1029.8320 - iou_metric: 0.3632 - val_loss: 1549.7430 - val_iou_metric: 0.0340
# Epoch 68/300
# 7/7 [==============================] - 1s 141ms/step - loss: 973.7754 - iou_metric: 0.3300 - val_loss: 1467.5737 - val_iou_metric: 0.0733
# Epoch 69/300
# 7/7 [==============================] - 1s 117ms/step - loss: 921.1382 - iou_metric: 0.3721 - val_loss: 1385.0472 - val_iou_metric: 0.0774
# Epoch 70/300
# 7/7 [==============================] - 1s 125ms/step - loss: 991.0920 - iou_metric: 0.3397 - val_loss: 1398.0210 - val_iou_metric: 0.0561
# Epoch 71/300
# 7/7 [==============================] - 1s 106ms/step - loss: 848.7114 - iou_metric: 0.3877 - val_loss: 1521.1465 - val_iou_metric: 0.0397
# Epoch 72/300
# 7/7 [==============================] - 1s 109ms/step - loss: 917.2858 - iou_metric: 0.3782 - val_loss: 1387.1780 - val_iou_metric: 0.0636
# Epoch 73/300
# 7/7 [==============================] - 1s 105ms/step - loss: 843.2487 - iou_metric: 0.4215 - val_loss: 1401.8010 - val_iou_metric: 0.0672
# Epoch 74/300
# 7/7 [==============================] - 1s 109ms/step - loss: 835.3994 - iou_metric: 0.4396 - val_loss: 1159.3303 - val_iou_metric: 0.0975
# Epoch 75/300
# 7/7 [==============================] - 1s 106ms/step - loss: 785.6355 - iou_metric: 0.4384 - val_loss: 1462.8683 - val_iou_metric: 0.0817
# Epoch 76/300
# 7/7 [==============================] - 1s 126ms/step - loss: 749.6515 - iou_metric: 0.4389 - val_loss: 1460.1277 - val_iou_metric: 0.0466
# Epoch 77/300
# Epoch 115/300
# 7/7 [==============================] - 1s 107ms/step - loss: 581.0256 - iou_metric: 0.5301 - val_loss: 923.2553 - val_iou_metric: 0.1876
# Epoch 116/300
# 7/7 [==============================] - 1s 107ms/step - loss: 568.4573 - iou_metric: 0.5662 - val_loss: 1068.2610 - val_iou_metric: 0.2303
# Epoch 117/300
# 7/7 [==============================] - 1s 108ms/step - loss: 535.4974 - iou_metric: 0.5445 - val_loss: 1044.2142 - val_iou_metric: 0.2183
# Epoch 118/300
# 7/7 [==============================] - 1s 108ms/step - loss: 480.7813 - iou_metric: 0.5097 - val_loss: 1244.0885 - val_iou_metric: 0.2033
# Epoch 119/300
# 7/7 [==============================] - 1s 108ms/step - loss: 463.8782 - iou_metric: 0.5515 - val_loss: 1233.4185 - val_iou_metric: 0.1551
# Epoch 120/300
# 7/7 [==============================] - 1s 109ms/step - loss: 655.2378 - iou_metric: 0.5357 - val_loss: 1335.6793 - val_iou_metric: 0.0918
# Epoch 121/300
# 7/7 [==============================] - 1s 108ms/step - loss: 867.9983 - iou_metric: 0.4980 - val_loss: 980.1672 - val_iou_metric: 0.2526
# Epoch 122/300
# 7/7 [==============================] - 1s 106ms/step - loss: 721.2869 - iou_metric: 0.4951 - val_loss: 931.2773 - val_iou_metric: 0.2182
# Epoch 123/300
# 7/7 [==============================] - 1s 109ms/step - loss: 564.0861 - iou_metric: 0.5594 - val_loss: 916.2324 - val_iou_metric: 0.2103
# Epoch 124/300
# 7/7 [==============================] - 1s 112ms/step - loss: 609.0880 - iou_metric: 0.5408 - val_loss: 1186.4534 - val_iou_metric: 0.2341
# Epoch 125/300
# 7/7 [==============================] - 1s 109ms/step - loss: 513.8273 - iou_metric: 0.5419 - val_loss: 1191.8359 - val_iou_metric: 0.1861
# Epoch 126/300
# 7/7 [==============================] - 1s 119ms/step - loss: 549.1008 - iou_metric: 0.5371 - val_loss: 1108.0325 - val_iou_metric: 0.1913
# Epoch 127/300
# 7/7 [==============================] - 1s 130ms/step - loss: 472.2701 - iou_metric: 0.5102 - val_loss: 1068.3364 - val_iou_metric: 0.1636
# Epoch 128/300
# 7/7 [==============================] - 1s 122ms/step - loss: 650.6904 - iou_metric: 0.5385 - val_loss: 1101.7815 - val_iou_metric: 0.1999
# Epoch 129/300
# 7/7 [==============================] - 1s 115ms/step - loss: 531.5710 - iou_metric: 0.5198 - val_loss: 1206.7942 - val_iou_metric: 0.1706
# Epoch 130/300
# 7/7 [==============================] - 1s 108ms/step - loss: 554.2813 - iou_metric: 0.5384 - val_loss: 985.3152 - val_iou_metric: 0.2013
# Epoch 131/300
# 7/7 [==============================] - 1s 111ms/step - loss: 446.8792 - iou_metric: 0.6005 - val_loss: 964.6700 - val_iou_metric: 0.2415
# Epoch 132/300
# 7/7 [==============================] - 1s 108ms/step - loss: 496.6716 - iou_metric: 0.5987 - val_loss: 1013.1602 - val_iou_metric: 0.2494
# Epoch 133/300
# 7/7 [==============================] - 1s 108ms/step - loss: 537.0685 - iou_metric: 0.6127 - val_loss: 1040.4622 - val_iou_metric: 0.2678
# Epoch 153/300
# 7/7 [==============================] - 1s 107ms/step - loss: 487.8171 - iou_metric: 0.6218 - val_loss: 1035.1121 - val_iou_metric: 0.2297
# Epoch 154/300
# 7/7 [==============================] - 1s 108ms/step - loss: 453.0719 - iou_metric: 0.6036 - val_loss: 1018.2961 - val_iou_metric: 0.2655
# Epoch 155/300
# 7/7 [==============================] - 1s 105ms/step - loss: 494.5221 - iou_metric: 0.6359 - val_loss: 1036.6293 - val_iou_metric: 0.2763
# Epoch 156/300
# 7/7 [==============================] - 1s 107ms/step - loss: 492.7617 - iou_metric: 0.6598 - val_loss: 958.6449 - val_iou_metric: 0.2763
# Epoch 157/300
# 7/7 [==============================] - 1s 107ms/step - loss: 517.0025 - iou_metric: 0.6474 - val_loss: 1145.1316 - val_iou_metric: 0.2090
# Epoch 158/300
# 7/7 [==============================] - 1s 106ms/step - loss: 536.4000 - iou_metric: 0.6510 - val_loss: 1067.2229 - val_iou_metric: 0.2607
# Epoch 159/300
# 7/7 [==============================] - 1s 109ms/step - loss: 381.6177 - iou_metric: 0.6270 - val_loss: 1247.9246 - val_iou_metric: 0.2138
# Epoch 160/300
# 7/7 [==============================] - 1s 125ms/step - loss: 512.8028 - iou_metric: 0.5849 - val_loss: 1193.7938 - val_iou_metric: 0.2592
# Epoch 161/300
# 7/7 [==============================] - 1s 127ms/step - loss: 550.3894 - iou_metric: 0.5628 - val_loss: 1091.4083 - val_iou_metric: 0.2000
# Epoch 162/300
# 7/7 [==============================] - 1s 135ms/step - loss: 545.6276 - iou_metric: 0.5815 - val_loss: 1196.1577 - val_iou_metric: 0.1530
# Epoch 163/300
# 7/7 [==============================] - 1s 116ms/step - loss: 433.7445 - iou_metric: 0.6280 - val_loss: 1052.8979 - val_iou_metric: 0.2075
# Epoch 164/300
# 7/7 [==============================] - 1s 108ms/step - loss: 476.6783 - iou_metric: 0.6601 - val_loss: 1019.4535 - val_iou_metric: 0.2185
# Epoch 165/300
# 7/7 [==============================] - 1s 110ms/step - loss: 470.8393 - iou_metric: 0.6225 - val_loss: 1225.3085 - val_iou_metric: 0.1783
# Epoch 166/300
# 7/7 [==============================] - 1s 108ms/step - loss: 543.4351 - iou_metric: 0.6301 - val_loss: 1072.4052 - val_iou_metric: 0.1922
# Epoch 167/300
# 7/7 [==============================] - 1s 108ms/step - loss: 472.4321 - iou_metric: 0.5976 - val_loss: 1053.1592 - val_iou_metric: 0.2551
# Epoch 168/300
# 7/7 [==============================] - 1s 109ms/step - loss: 476.9702 - iou_metric: 0.6492 - val_loss: 1226.2303 - val_iou_metric: 0.2364
# Epoch 169/300
# 7/7 [==============================] - 1s 107ms/step - loss: 515.9912 - iou_metric: 0.5724 - val_loss: 1150.4504 - val_iou_metric: 0.2407
# Epoch 170/300
# 7/7 [==============================] - 1s 109ms/step - loss: 489.3041 - iou_metric: 0.5917 - val_loss: 1184.4843 - val_iou_metric: 0.2538
# Epoch 171/300
# 7/7 [==============================] - 1s 106ms/step - loss: 481.3122 - iou_metric: 0.6129 - val_loss: 1276.2979 - val_iou_metric: 0.2249
# Epoch 172/300
# 7/7 [==============================] - 1s 106ms/step - loss: 526.1660 - iou_metric: 0.5826 - val_loss: 1281.3704 - val_iou_metric: 0.1834
# Epoch 173/300
# 7/7 [==============================] - 1s 108ms/step - loss: 550.0900 - iou_metric: 0.5594 - val_loss: 1082.3608 - val_iou_metric: 0.2169
# Epoch 174/300
# 7/7 [==============================] - 1s 110ms/step - loss: 440.7265 - iou_metric: 0.6362 - val_loss: 1082.1654 - val_iou_metric: 0.2149
# Epoch 175/300
# 7/7 [==============================] - 1s 107ms/step - loss: 487.2730 - iou_metric: 0.6400 - val_loss: 1070.1100 - val_iou_metric: 0.2971
# Epoch 176/300
# 7/7 [==============================] - 1s 107ms/step - loss: 445.9731 - iou_metric: 0.6700 - val_loss: 1061.7124 - val_iou_metric: 0.2701
# Epoch 177/300
# 7/7 [==============================] - 1s 126ms/step - loss: 543.6905 - iou_metric: 0.6912 - val_loss: 1018.1772 - val_iou_metric: 0.2357
# Epoch 178/300
# 7/7 [==============================] - 1s 121ms/step - loss: 461.7742 - iou_metric: 0.6589 - val_loss: 921.0196 - val_iou_metric: 0.2423
# Epoch 179/300
# 7/7 [==============================] - 1s 136ms/step - loss: 502.3461 - iou_metric: 0.6609 - val_loss: 977.7416 - val_iou_metric: 0.2344
# Epoch 180/300
# 7/7 [==============================] - 1s 110ms/step - loss: 452.1132 - iou_metric: 0.6437 - val_loss: 1144.7369 - val_iou_metric: 0.2010
# Epoch 181/300
# 7/7 [==============================] - 1s 106ms/step - loss: 491.1150 - iou_metric: 0.5706 - val_loss: 955.1002 - val_iou_metric: 0.1760
# Epoch 182/300
# 7/7 [==============================] - 1s 106ms/step - loss: 546.9606 - iou_metric: 0.5771 - val_loss: 1084.8176 - val_iou_metric: 0.2241
# Epoch 183/300
# 7/7 [==============================] - 1s 108ms/step - loss: 584.2690 - iou_metric: 0.6200 - val_loss: 915.3105 - val_iou_metric: 0.2428
# Epoch 184/300
# 7/7 [==============================] - 1s 109ms/step - loss: 432.5412 - iou_metric: 0.6121 - val_loss: 1112.0466 - val_iou_metric: 0.1895
# Epoch 185/300
# 7/7 [==============================] - 1s 105ms/step - loss: 536.5206 - iou_metric: 0.5918 - val_loss: 1044.5605 - val_iou_metric: 0.2398
# Epoch 186/300
# 7/7 [==============================] - 1s 106ms/step - loss: 574.9360 - iou_metric: 0.5449 - val_loss: 1095.2510 - val_iou_metric: 0.2073
# Epoch 187/300
# 7/7 [==============================] - 1s 107ms/step - loss: 536.6089 - iou_metric: 0.5800 - val_loss: 1299.5297 - val_iou_metric: 0.1102
# Epoch 188/300
# 7/7 [==============================] - 1s 105ms/step - loss: 596.0933 - iou_metric: 0.5795 - val_loss: 1245.3970 - val_iou_metric: 0.1913
# Epoch 189/300
# 7/7 [==============================] - 1s 109ms/step - loss: 445.4041 - iou_metric: 0.5943 - val_loss: 1162.7811 - val_iou_metric: 0.2499
# Epoch 190/300
# 7/7 [==============================] - 1s 108ms/step - loss: 406.5477 - iou_metric: 0.6149 - val_loss: 1057.7935 - val_iou_metric: 0.2299
# Epoch 191/300
# 7/7 [==============================] - 1s 108ms/step - loss: 477.2543 - iou_metric: 0.6621 - val_loss: 1162.8044 - val_iou_metric: 0.2592
# Epoch 192/300
# 7/7 [==============================] - 1s 106ms/step - loss: 481.9068 - iou_metric: 0.6688 - val_loss: 1102.1625 - val_iou_metric: 0.2692
# Epoch 193/300
# 7/7 [==============================] - 1s 113ms/step - loss: 508.7351 - iou_metric: 0.6251 - val_loss: 996.7747 - val_iou_metric: 0.2686
# Epoch 194/300
# 7/7 [==============================] - 1s 127ms/step - loss: 480.9006 - iou_metric: 0.6671 - val_loss: 1166.2083 - val_iou_metric: 0.2408
# Epoch 195/300
# 7/7 [==============================] - 1s 146ms/step - loss: 494.6106 - iou_metric: 0.6045 - val_loss: 1020.7022 - val_iou_metric: 0.2801
# Epoch 196/300
# 7/7 [==============================] - 1s 144ms/step - loss: 417.9514 - iou_metric: 0.6622 - val_loss: 1026.3615 - val_iou_metric: 0.2818
# Epoch 197/300
# 7/7 [==============================] - 1s 105ms/step - loss: 444.7042 - iou_metric: 0.6644 - val_loss: 1109.5443 - val_iou_metric: 0.2707
# Epoch 198/300
# 7/7 [==============================] - 1s 107ms/step - loss: 421.1768 - iou_metric: 0.6839 - val_loss: 1115.1272 - val_iou_metric: 0.2682
# Epoch 199/300
# 7/7 [==============================] - 1s 108ms/step - loss: 554.3728 - iou_metric: 0.6412 - val_loss: 1092.6141 - val_iou_metric: 0.2479
# Epoch 200/300
# 7/7 [==============================] - 1s 108ms/step - loss: 525.3860 - iou_metric: 0.6022 - val_loss: 1046.6621 - val_iou_metric: 0.2739
# Epoch 201/300
# 7/7 [==============================] - 1s 107ms/step - loss: 542.0057 - iou_metric: 0.6192 - val_loss: 1047.6235 - val_iou_metric: 0.2752
# Epoch 202/300
# 7/7 [==============================] - 1s 108ms/step - loss: 529.5870 - iou_metric: 0.6179 - val_loss: 1052.1106 - val_iou_metric: 0.2601
# Epoch 203/300
# 7/7 [==============================] - 1s 108ms/step - loss: 469.3454 - iou_metric: 0.6661 - val_loss: 1141.1255 - val_iou_metric: 0.2832
# Epoch 204/300
# 7/7 [==============================] - 1s 109ms/step - loss: 497.6072 - iou_metric: 0.6669 - val_loss: 1148.8691 - val_iou_metric: 0.2654
# Epoch 205/300
# 7/7 [==============================] - 1s 107ms/step - loss: 478.7214 - iou_metric: 0.6918 - val_loss: 1079.7504 - val_iou_metric: 0.2678
# Epoch 206/300
# 7/7 [==============================] - 1s 106ms/step - loss: 503.0045 - iou_metric: 0.7009 - val_loss: 1029.2914 - val_iou_metric: 0.2891
# Epoch 207/300
# 7/7 [==============================] - 1s 105ms/step - loss: 425.8813 - iou_metric: 0.6687 - val_loss: 1160.5319 - val_iou_metric: 0.2926
# Epoch 208/300
# 7/7 [==============================] - 1s 109ms/step - loss: 472.1818 - iou_metric: 0.6560 - val_loss: 1080.2118 - val_iou_metric: 0.2577
# Epoch 209/300
# 7/7 [==============================] - 1s 104ms/step - loss: 484.0047 - iou_metric: 0.6216 - val_loss: 1056.1702 - val_iou_metric: 0.2495
# Epoch 210/300
# 7/7 [==============================] - 1s 129ms/step - loss: 488.4129 - iou_metric: 0.5825 - val_loss: 1406.1179 - val_iou_metric: 0.1882
# Epoch 211/300
# 7/7 [==============================] - 1s 123ms/step - loss: 579.5989 - iou_metric: 0.6100 - val_loss: 1167.7157 - val_iou_metric: 0.2448
# Epoch 212/300
# 7/7 [==============================] - 1s 127ms/step - loss: 500.2458 - iou_metric: 0.6625 - val_loss: 1068.9237 - val_iou_metric: 0.2710
# Epoch 213/300
# 7/7 [==============================] - 1s 126ms/step - loss: 417.7441 - iou_metric: 0.6870 - val_loss: 1029.3630 - val_iou_metric: 0.2838
# Epoch 214/300
# 7/7 [==============================] - 1s 107ms/step - loss: 437.6027 - iou_metric: 0.6627 - val_loss: 1113.6256 - val_iou_metric: 0.2411
# Epoch 215/300
# 7/7 [==============================] - 1s 106ms/step - loss: 376.5911 - iou_metric: 0.7123 - val_loss: 992.1467 - val_iou_metric: 0.2388
# Epoch 216/300
# 7/7 [==============================] - 1s 111ms/step - loss: 480.6270 - iou_metric: 0.6679 - val_loss: 1072.7683 - val_iou_metric: 0.2226
# Epoch 217/300
# 7/7 [==============================] - 1s 108ms/step - loss: 419.8410 - iou_metric: 0.7136 - val_loss: 1213.1731 - val_iou_metric: 0.2520
# Epoch 218/300
# 7/7 [==============================] - 1s 106ms/step - loss: 393.2138 - iou_metric: 0.7053 - val_loss: 1080.5801 - val_iou_metric: 0.2533
# Epoch 219/300
# 7/7 [==============================] - 1s 108ms/step - loss: 371.7989 - iou_metric: 0.6743 - val_loss: 1146.4685 - val_iou_metric: 0.2760
# Epoch 220/300
# 7/7 [==============================] - 1s 107ms/step - loss: 478.0852 - iou_metric: 0.6701 - val_loss: 1027.2734 - val_iou_metric: 0.2516
# Epoch 221/300
# 7/7 [==============================] - 1s 108ms/step - loss: 565.7579 - iou_metric: 0.4902 - val_loss: 1149.9976 - val_iou_metric: 0.1999
# Epoch 222/300
# 7/7 [==============================] - 1s 108ms/step - loss: 624.4797 - iou_metric: 0.5718 - val_loss: 1088.5492 - val_iou_metric: 0.1963
# Epoch 223/300
# 7/7 [==============================] - 1s 108ms/step - loss: 469.9873 - iou_metric: 0.5609 - val_loss: 1068.8364 - val_iou_metric: 0.2744
# Epoch 224/300
# 7/7 [==============================] - 1s 108ms/step - loss: 448.3095 - iou_metric: 0.6358 - val_loss: 1077.6652 - val_iou_metric: 0.2192
# Epoch 225/300
# 7/7 [==============================] - 1s 107ms/step - loss: 481.4482 - iou_metric: 0.6191 - val_loss: 970.7133 - val_iou_metric: 0.2696
# Epoch 226/300
# 7/7 [==============================] - 1s 109ms/step - loss: 453.6557 - iou_metric: 0.6662 - val_loss: 1067.3828 - val_iou_metric: 0.2805
# Epoch 227/300
# 7/7 [==============================] - 1s 157ms/step - loss: 506.9276 - iou_metric: 0.6510 - val_loss: 1014.5958 - val_iou_metric: 0.2761
# Epoch 228/300
# 7/7 [==============================] - 1s 169ms/step - loss: 465.7074 - iou_metric: 0.6744 - val_loss: 985.0979 - val_iou_metric: 0.2698
# Epoch 229/300
# 7/7 [==============================] - 1s 183ms/step - loss: 438.7000 - iou_metric: 0.6847 - val_loss: 989.7703 - val_iou_metric: 0.2744
# Epoch 230/300
# 7/7 [==============================] - 1s 149ms/step - loss: 404.5656 - iou_metric: 0.7064 - val_loss: 1024.4711 - val_iou_metric: 0.2760
# Epoch 231/300
# 7/7 [==============================] - 1s 148ms/step - loss: 437.4240 - iou_metric: 0.7105 - val_loss: 1029.8939 - val_iou_metric: 0.2621
# Epoch 232/300
# 7/7 [==============================] - 1s 147ms/step - loss: 499.8864 - iou_metric: 0.6956 - val_loss: 967.0574 - val_iou_metric: 0.2730
# Epoch 233/300
# 7/7 [==============================] - 1s 166ms/step - loss: 450.3527 - iou_metric: 0.7225 - val_loss: 1047.4987 - val_iou_metric: 0.2856
# Epoch 234/300
# 7/7 [==============================] - 1s 112ms/step - loss: 499.0444 - iou_metric: 0.7289 - val_loss: 956.9771 - val_iou_metric: 0.2758
# Epoch 235/300
# 7/7 [==============================] - 1s 108ms/step - loss: 526.5123 - iou_metric: 0.7367 - val_loss: 915.7246 - val_iou_metric: 0.2768
# Epoch 236/300
# 7/7 [==============================] - 1s 113ms/step - loss: 480.9304 - iou_metric: 0.6917 - val_loss: 992.2698 - val_iou_metric: 0.2412
# Epoch 237/300
# 7/7 [==============================] - 1s 108ms/step - loss: 489.2012 - iou_metric: 0.7157 - val_loss: 964.0566 - val_iou_metric: 0.2811
# Epoch 238/300
# 7/7 [==============================] - 1s 107ms/step - loss: 444.1574 - iou_metric: 0.7468 - val_loss: 1039.2478 - val_iou_metric: 0.2826
# Epoch 239/300
# 7/7 [==============================] - 1s 109ms/step - loss: 439.3652 - iou_metric: 0.6734 - val_loss: 1058.8137 - val_iou_metric: 0.2824
# Epoch 240/300
# 7/7 [==============================] - 1s 109ms/step - loss: 485.2813 - iou_metric: 0.6716 - val_loss: 1119.9277 - val_iou_metric: 0.2992
# Epoch 241/300
# 7/7 [==============================] - 1s 107ms/step - loss: 450.2914 - iou_metric: 0.6757 - val_loss: 902.5370 - val_iou_metric: 0.2632
# Epoch 242/300
# 7/7 [==============================] - 1s 126ms/step - loss: 382.3559 - iou_metric: 0.6740 - val_loss: 937.5959 - val_iou_metric: 0.2650
# Epoch 243/300
# 7/7 [==============================] - 1s 123ms/step - loss: 460.8864 - iou_metric: 0.6728 - val_loss: 939.6355 - val_iou_metric: 0.2280
# Epoch 244/300
# 7/7 [==============================] - 1s 126ms/step - loss: 485.8204 - iou_metric: 0.6377 - val_loss: 961.8658 - val_iou_metric: 0.2782
# Epoch 245/300
# 7/7 [==============================] - 1s 120ms/step - loss: 522.9443 - iou_metric: 0.6804 - val_loss: 932.6863 - val_iou_metric: 0.2644
# Epoch 246/300
# 7/7 [==============================] - 1s 109ms/step - loss: 426.4781 - iou_metric: 0.7148 - val_loss: 956.1541 - val_iou_metric: 0.2646
# Epoch 247/300
# 7/7 [==============================] - 1s 108ms/step - loss: 563.0594 - iou_metric: 0.6964 - val_loss: 996.7060 - val_iou_metric: 0.2805
# Epoch 248/300
# 7/7 [==============================] - 1s 106ms/step - loss: 399.9747 - iou_metric: 0.7137 - val_loss: 1128.2662 - val_iou_metric: 0.2882
# Epoch 249/300
# 7/7 [==============================] - 1s 107ms/step - loss: 512.9368 - iou_metric: 0.6686 - val_loss: 1123.5559 - val_iou_metric: 0.2872
# Epoch 250/300
# 7/7 [==============================] - 1s 105ms/step - loss: 486.8051 - iou_metric: 0.6614 - val_loss: 985.3484 - val_iou_metric: 0.2641
# Epoch 251/300
# 7/7 [==============================] - 1s 109ms/step - loss: 479.3139 - iou_metric: 0.6360 - val_loss: 1104.1367 - val_iou_metric: 0.2482
# Epoch 252/300
# 7/7 [==============================] - 1s 108ms/step - loss: 506.4022 - iou_metric: 0.6476 - val_loss: 1117.3221 - val_iou_metric: 0.2586
# Epoch 253/300
# 7/7 [==============================] - 1s 108ms/step - loss: 473.9245 - iou_metric: 0.6759 - val_loss: 1099.5414 - val_iou_metric: 0.2623
# Epoch 254/300
# 7/7 [==============================] - 1s 106ms/step - loss: 456.8881 - iou_metric: 0.6938 - val_loss: 1072.7677 - val_iou_metric: 0.2355
# Epoch 255/300
# 7/7 [==============================] - 1s 111ms/step - loss: 426.8784 - iou_metric: 0.6696 - val_loss: 1124.2958 - val_iou_metric: 0.2609
# Epoch 256/300
# 7/7 [==============================] - 1s 104ms/step - loss: 413.6155 - iou_metric: 0.6635 - val_loss: 1011.9429 - val_iou_metric: 0.2775
# Epoch 257/300
# 7/7 [==============================] - 1s 107ms/step - loss: 429.8928 - iou_metric: 0.6675 - val_loss: 986.1750 - val_iou_metric: 0.2718
# Epoch 258/300
# 7/7 [==============================] - 1s 110ms/step - loss: 451.7587 - iou_metric: 0.7074 - val_loss: 1025.3832 - val_iou_metric: 0.2850
# Epoch 259/300
# 7/7 [==============================] - 1s 129ms/step - loss: 467.0009 - iou_metric: 0.7189 - val_loss: 1033.6222 - val_iou_metric: 0.2966
# Epoch 260/300
# 7/7 [==============================] - 1s 129ms/step - loss: 501.0301 - iou_metric: 0.7035 - val_loss: 1002.9984 - val_iou_metric: 0.2875
# Epoch 261/300
# 7/7 [==============================] - 1s 134ms/step - loss: 464.7712 - iou_metric: 0.7336 - val_loss: 1110.1787 - val_iou_metric: 0.2965
# Epoch 262/300
# 7/7 [==============================] - 1s 119ms/step - loss: 400.4629 - iou_metric: 0.7329 - val_loss: 1115.9050 - val_iou_metric: 0.2910
# Epoch 263/300
# 7/7 [==============================] - 1s 106ms/step - loss: 492.4527 - iou_metric: 0.7175 - val_loss: 1043.7181 - val_iou_metric: 0.2914
# Epoch 264/300
# 7/7 [==============================] - 1s 109ms/step - loss: 430.2967 - iou_metric: 0.7467 - val_loss: 991.3334 - val_iou_metric: 0.2793
# Epoch 265/300
# 7/7 [==============================] - 1s 109ms/step - loss: 479.8951 - iou_metric: 0.6944 - val_loss: 1152.9124 - val_iou_metric: 0.2827
# Epoch 266/300
# 7/7 [==============================] - 1s 108ms/step - loss: 423.9359 - iou_metric: 0.7551 - val_loss: 1106.6165 - val_iou_metric: 0.2802
# Epoch 267/300
# 7/7 [==============================] - 1s 108ms/step - loss: 385.9474 - iou_metric: 0.7653 - val_loss: 1159.9817 - val_iou_metric: 0.2748
# Epoch 268/300
# 7/7 [==============================] - 1s 107ms/step - loss: 442.0653 - iou_metric: 0.7397 - val_loss: 1051.9545 - val_iou_metric: 0.2665
# Epoch 269/300
# 7/7 [==============================] - 1s 109ms/step - loss: 437.0400 - iou_metric: 0.7247 - val_loss: 1152.7708 - val_iou_metric: 0.2925
# Epoch 270/300
# 7/7 [==============================] - 1s 108ms/step - loss: 513.3094 - iou_metric: 0.6932 - val_loss: 1076.9208 - val_iou_metric: 0.2884
# Epoch 271/300
# 7/7 [==============================] - 1s 106ms/step - loss: 425.4895 - iou_metric: 0.6828 - val_loss: 1097.7450 - val_iou_metric: 0.2610
# Epoch 272/300
# 7/7 [==============================] - 1s 112ms/step - loss: 379.1530 - iou_metric: 0.6887 - val_loss: 1059.2712 - val_iou_metric: 0.2662
# Epoch 273/300
# 7/7 [==============================] - 1s 109ms/step - loss: 493.1324 - iou_metric: 0.6790 - val_loss: 950.1614 - val_iou_metric: 0.2534
# Epoch 274/300
# 7/7 [==============================] - 1s 106ms/step - loss: 451.7292 - iou_metric: 0.6804 - val_loss: 927.8499 - val_iou_metric: 0.2805
# Epoch 275/300
# 7/7 [==============================] - 1s 115ms/step - loss: 450.0319 - iou_metric: 0.6724 - val_loss: 1120.8345 - val_iou_metric: 0.2793
# Epoch 276/300
# 7/7 [==============================] - 1s 125ms/step - loss: 490.6544 - iou_metric: 0.7044 - val_loss: 1011.8148 - val_iou_metric: 0.2649
# Epoch 277/300
# 7/7 [==============================] - 1s 123ms/step - loss: 486.4314 - iou_metric: 0.6933 - val_loss: 1133.5081 - val_iou_metric: 0.2646
# Epoch 278/300
# 7/7 [==============================] - 1s 134ms/step - loss: 433.2724 - iou_metric: 0.7215 - val_loss: 997.1113 - val_iou_metric: 0.2707
# Epoch 279/300
# 7/7 [==============================] - 1s 111ms/step - loss: 408.2199 - iou_metric: 0.6928 - val_loss: 1054.3019 - val_iou_metric: 0.2748
# Epoch 280/300
# 7/7 [==============================] - 1s 109ms/step - loss: 388.1798 - iou_metric: 0.7268 - val_loss: 999.6191 - val_iou_metric: 0.2772
# Epoch 281/300
# 7/7 [==============================] - 1s 108ms/step - loss: 429.8231 - iou_metric: 0.7037 - val_loss: 1046.5208 - val_iou_metric: 0.2719
# Epoch 282/300
# 7/7 [==============================] - 1s 107ms/step - loss: 524.0695 - iou_metric: 0.7089 - val_loss: 1094.4647 - val_iou_metric: 0.2845
# Epoch 283/300
# 7/7 [==============================] - 1s 108ms/step - loss: 520.7084 - iou_metric: 0.6464 - val_loss: 1010.6934 - val_iou_metric: 0.2889
# Epoch 284/300
# 7/7 [==============================] - 1s 108ms/step - loss: 444.0652 - iou_metric: 0.6994 - val_loss: 1073.2292 - val_iou_metric: 0.2466
# Epoch 285/300
# 7/7 [==============================] - 1s 108ms/step - loss: 459.7840 - iou_metric: 0.6903 - val_loss: 1243.2258 - val_iou_metric: 0.2142
# Epoch 286/300
# 7/7 [==============================] - 1s 107ms/step - loss: 398.0949 - iou_metric: 0.6541 - val_loss: 1221.3169 - val_iou_metric: 0.2283
# Epoch 287/300
# 7/7 [==============================] - 1s 108ms/step - loss: 536.9742 - iou_metric: 0.7027 - val_loss: 1131.4110 - val_iou_metric: 0.2379
# Epoch 288/300
# 7/7 [==============================] - 1s 110ms/step - loss: 451.8843 - iou_metric: 0.7211 - val_loss: 1059.2936 - val_iou_metric: 0.2423
# Epoch 289/300
# 7/7 [==============================] - 1s 106ms/step - loss: 507.8719 - iou_metric: 0.6651 - val_loss: 1108.5134 - val_iou_metric: 0.2651
# Epoch 290/300
# 7/7 [==============================] - 1s 106ms/step - loss: 390.8938 - iou_metric: 0.7236 - val_loss: 1068.1184 - val_iou_metric: 0.2708
# Epoch 291/300
# 7/7 [==============================] - 1s 106ms/step - loss: 418.3309 - iou_metric: 0.6651 - val_loss: 1019.2138 - val_iou_metric: 0.2708
# Epoch 292/300
# 7/7 [==============================] - 1s 128ms/step - loss: 389.6364 - iou_metric: 0.7353 - val_loss: 1131.3103 - val_iou_metric: 0.2702
# Epoch 293/300
# 7/7 [==============================] - 1s 137ms/step - loss: 452.1925 - iou_metric: 0.7402 - val_loss: 1013.9863 - val_iou_metric: 0.3232
# Epoch 294/300
# 7/7 [==============================] - 1s 128ms/step - loss: 494.3066 - iou_metric: 0.7302 - val_loss: 1082.0601 - val_iou_metric: 0.2563
# Epoch 295/300
# 7/7 [==============================] - 1s 127ms/step - loss: 508.2438 - iou_metric: 0.6997 - val_loss: 1151.1683 - val_iou_metric: 0.2823
# Epoch 296/300
# 7/7 [==============================] - 1s 110ms/step - loss: 416.9628 - iou_metric: 0.6836 - val_loss: 1114.6537 - val_iou_metric: 0.2387
# Epoch 297/300
# 7/7 [==============================] - 1s 106ms/step - loss: 467.1303 - iou_metric: 0.7141 - val_loss: 1081.4858 - val_iou_metric: 0.2835
# Epoch 298/300
# 7/7 [==============================] - 1s 107ms/step - loss: 499.4857 - iou_metric: 0.6989 - val_loss: 1094.3099 - val_iou_metric: 0.2713
# Epoch 299/300
# 7/7 [==============================] - 1s 108ms/step - loss: 431.1225 - iou_metric: 0.7374 - val_loss: 1117.6990 - val_iou_metric: 0.2535
# Epoch 300/300
# 7/7 [==============================] - 1s 106ms/step - loss: 499.7106 - iou_metric: 0.7004 - val_loss: 980.9028 - val_iou_metric: 0.2783

# %% [markdown]
# # 6. Test the model

# %%
def preview_all(test_data, model, threshold=0.1):
    for i, X in enumerate(test_data):
        X = X[np.newaxis, :, :, :]
        y = model.predict(X, verbose=0)
        show_predict(X[0], y[0], threshold=threshold)
        if i==21: break

preview_all(x_test, model, threshold=0.1)
